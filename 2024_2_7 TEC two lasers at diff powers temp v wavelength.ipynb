# %%
import pandas as pd

# %%
import numpy as np

# %%
# see temp v wavelength from two lasers at three diff powers and plotting them all on one graph

# %%
# importing data containing wavelength info

# %%
# laser 1
file1  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser1/15.01mA/12.001kOhm.csv'
file2  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser1/15.01mA/14.000kOhm.csv'
file3  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser1/15.01mA/16.000kOhm.csv'
file4  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser1/15.01mA/18.002kOhm.csv'

file5  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser1/20.01mA/12.001kOhm.csv'
file6  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser1/20.01mA/14.000kOhm.csv'
file7  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser1/20.01mA/16.000kOhm.csv'
file8  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser1/20.01mA/18.001kOhm.csv'

file9  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser1/25mA/12.000kOhm.csv'
file10  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser1/25mA/14.000kOhm.csv'
file11  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser1/25mA/16.003kOhm.csv'
file12  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser1/25mA/18.001kOhm.csv'

#laser 2
file13  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser2/15.02mA/12.001kOhm.csv'
file14  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser2/15.02mA/14.001kOhm.csv'
file15  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser2/15.02mA/16.002kOhm.csv'
file16  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser2/15.02mA/18.002kOhm.csv'

file17  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser2/20.01mA/12.000kOhm.csv'
file18  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser2/20.01mA/14.003kOhm.csv'
file19  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser2/20.01mA/16.003kOhm.csv'
file20  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser2/20.01mA/18.002kOhm.csv'

file21  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser2/25mA/12.000kOhm.csv'
file22  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser2/25mA/14.000kOhm.csv'
file23  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser2/25mA/16.001kOhm.csv'
file24  = '/Users/feb9528/Desktop/files/2024_2_7_TEC_laser2/25mA/18.001kOhm.csv'

# %%
# reading only from the Peak Position (nm [air]) column

df1  = pd.read_csv(file1,  skiprows=[0], usecols=[2])
df2  = pd.read_csv(file2,  skiprows=[0], usecols=[2])
df3  = pd.read_csv(file3,  skiprows=[0], usecols=[2])
df4  = pd.read_csv(file4,  skiprows=[0], usecols=[2])
df5  = pd.read_csv(file5,  skiprows=[0], usecols=[2])
df6  = pd.read_csv(file6,  skiprows=[0], usecols=[2])
df7  = pd.read_csv(file7,  skiprows=[0], usecols=[2])
df8  = pd.read_csv(file8,  skiprows=[0], usecols=[2])
df9  = pd.read_csv(file9,  skiprows=[0], usecols=[2])
df10  = pd.read_csv(file10,  skiprows=[0], usecols=[2])
df11  = pd.read_csv(file11,  skiprows=[0], usecols=[2])
df12  = pd.read_csv(file12,  skiprows=[0], usecols=[2])
df13  = pd.read_csv(file13,  skiprows=[0], usecols=[2])
df14  = pd.read_csv(file14,  skiprows=[0], usecols=[2])
df15  = pd.read_csv(file15,  skiprows=[0], usecols=[2])
df16  = pd.read_csv(file16,  skiprows=[0], usecols=[2])
df17  = pd.read_csv(file17,  skiprows=[0], usecols=[2])
df18  = pd.read_csv(file18,  skiprows=[0], usecols=[2])
df19  = pd.read_csv(file19,  skiprows=[0], usecols=[2])
df20  = pd.read_csv(file20,  skiprows=[0], usecols=[2])
df21  = pd.read_csv(file21,  skiprows=[0], usecols=[2])
df22  = pd.read_csv(file22,  skiprows=[0], usecols=[2])
df23  = pd.read_csv(file23,  skiprows=[0], usecols=[2])
df24  = pd.read_csv(file24,  skiprows=[0], usecols=[2])

# %%
# ignore empty values

df1  = df1.dropna()
df2  = df2.dropna()
df3  = df3.dropna()
df4  = df4.dropna()
df5  = df5.dropna()
df6  = df6.dropna()
df7  = df7.dropna()
df8  = df8.dropna()
df9  = df9.dropna()
df10  = df10.dropna()
df11  = df11.dropna()
df12  = df12.dropna()
df13  = df13.dropna()
df14  = df14.dropna()
df15  = df15.dropna()
df16  = df16.dropna()
df17  = df17.dropna()
df18  = df18.dropna()
df19  = df19.dropna()
df20  = df20.dropna()
df21  = df21.dropna()
df22  = df22.dropna()
df23  = df23.dropna()
df24  = df24.dropna()

# %%
# read the wavelength values from each run to an array

lambda1  = df1.values
lambda2  = df2.values
lambda3  = df3.values
lambda4  = df4.values
lambda5  = df5.values
lambda6  = df6.values
lambda7  = df7.values
lambda8  = df8.values
lambda9  = df9.values
lambda10  = df10.values
lambda11  = df11.values
lambda12  = df12.values
lambda13  = df13.values
lambda14  = df14.values
lambda15  = df15.values
lambda16  = df16.values
lambda17  = df17.values
lambda18  = df18.values
lambda19  = df19.values
lambda20  = df20.values
lambda21  = df21.values
lambda22  = df22.values
lambda23  = df23.values
lambda24  = df24.values

# %%
# Finding average wavelength of each data run

# %%
# append wavelengths to an array, separating by laser and power
wavelengths1_15 = []
wavelengths1_20 = []
wavelengths1_25 = []

wavelengths2_15 = []
wavelengths2_20 = []
wavelengths2_25 = []

# %%
avg1 = 0
for i in lambda1:
    avg1 = avg1 + i[0]
    
avg1 = avg1/len(lambda1)
wavelengths1_15.append(avg1)

avg2 = 0
for i in lambda2:
    avg2 = avg2 + i[0]
    
avg2 = avg2/len(lambda2)
wavelengths1_15.append(avg2)

avg3 = 0
for i in lambda3:
    avg3 = avg3 + i[0]
    
avg3 = avg3/len(lambda3)
wavelengths1_15.append(avg3)

#avg4 = 0
#for i in lambda4:
#    avg4 = avg4 + i[0]
    
#avg4 = avg4/len(lambda4)
#wavelengths1_15.append(avg4)
wavelengths1_15.append(668.7754517)

avg5 = 0
for i in lambda5:
    avg5 = avg5 + i[0]
    
avg5 = avg5/len(lambda5)
wavelengths1_20.append(avg5)

avg6 = 0
for i in lambda6:
    avg6 = avg6 + i[0]
    
avg6 = avg6/len(lambda6)
wavelengths1_20.append(avg6)

avg7 = 0
for i in lambda7:
    avg7 = avg7 + i[0]
    
avg7 = avg7/len(lambda7)
wavelengths1_20.append(avg7)

avg8 = 0
for i in lambda8:
    avg8 = avg8 + i[0]
    
avg8 = avg8/len(lambda8)
wavelengths1_20.append(avg8)

avg9 = 0
for i in lambda9:
    avg9 = avg9 + i[0]
    
avg9 = avg9/len(lambda9)
wavelengths1_25.append(avg9)

avg10 = 0
for i in lambda10:
    avg10 = avg10 + i[0]
    
avg10 = avg10/len(lambda10)
wavelengths1_25.append(avg10)

avg11 = 0
for i in lambda11:
    avg11 = avg11 + i[0]
    
avg11 = avg11/len(lambda11)
wavelengths1_25.append(avg11)

avg12 = 0
for i in lambda12:
    avg12 = avg12 + i[0]
    
avg12 = avg12/len(lambda12)
wavelengths1_25.append(avg12)

avg13 = 0
for i in lambda13:
    avg13 = avg13 + i[0]
    
avg13 = avg13/len(lambda13)
wavelengths2_15.append(avg13)

avg14 = 0
for i in lambda14:
    avg14 = avg14 + i[0]
    
avg14 = avg14/len(lambda14)
wavelengths2_15.append(avg14)

avg15 = 0
for i in lambda15:
    avg15 = avg15 + i[0]
    
avg15 = avg15/len(lambda15)
wavelengths2_15.append(avg15)

avg16 = 0
for i in lambda16:
    avg16 = avg16 + i[0]
    
avg16 = avg16/len(lambda16)
wavelengths2_15.append(avg16)

avg17 = 0
for i in lambda17:
    avg17 = avg17 + i[0]
    
avg17 = avg17/len(lambda17)
wavelengths2_20.append(avg17)

avg18 = 0
for i in lambda18:
    avg18 = avg18 + i[0]
    
avg18 = avg18/len(lambda18)
wavelengths2_20.append(avg18)

avg19 = 0
for i in lambda19:
    avg19 = avg19 + i[0]
    
avg19 = avg19/len(lambda19)
wavelengths2_20.append(avg19)

avg20 = 0
for i in lambda20:
    avg20 = avg20 + i[0]
    
avg20 = avg20/len(lambda20)
wavelengths2_20.append(avg20)

avg21 = 0
for i in lambda21:
    avg21 = avg21 + i[0]
    
avg21 = avg21/len(lambda21)
wavelengths2_25.append(avg21)

avg22 = 0
for i in lambda22:
    avg22 = avg22 + i[0]
    
avg22 = avg22/len(lambda22)
wavelengths2_25.append(avg22)

avg23 = 0
for i in lambda23:
    avg23 = avg23 + i[0]
    
avg23 = avg23/len(lambda23)
wavelengths2_25.append(avg23)

avg24 = 0
for i in lambda24:
    avg24 = avg24 + i[0]
    
avg24 = avg24/len(lambda24)
wavelengths2_25.append(avg24)

# %%
# list of resistances for each laser and power
res1_15 = [12.001, 14.000, 16.000, 18.002]
res1_20 = [12.001, 14.000, 16.000, 18.001]
res1_25 = [12.000, 14.000, 16.003, 18.001]

res2_15 = [12.001, 14.001, 16.002, 18.002]
res2_20 = [12.000, 14.003, 16.003, 18.002]
res2_25 = [12.000, 14.000, 16.001, 18.001]

# %%
# Using the thermistor resistance to temperature forumula from Thorlabs TEC manual and specs of HL6756MG laser

# %%
# nominal temperature in Kelvin
T_o = 298.15

# thermistor nominal resistance at nominal temperature in kOhm
R_o = 10

# energy constant/B value in Kelvin
B = 3977

# append temperatures to a list for each run
temps1_15 = []
temps1_20 = []
temps1_25 = []

temps2_15 = []
temps2_20 = []
temps2_25 = []

# %%
# Converting resistance to temperature and changing temp in Kelvin to Celcius for each run

for i in range(0, len(wavelengths1_15)):
    T_K = (B * T_o)/((T_o * np.log(res1_15[i]/R_o)) + B)
    T_C = T_K - 273.15
    temps1_15.append(T_C)
    
for i in range(0, len(wavelengths1_20)):
    T_K = (B * T_o)/((T_o * np.log(res1_20[i]/R_o)) + B)
    T_C = T_K - 273.15
    temps1_20.append(T_C)
    
for i in range(0, len(wavelengths1_25)):
    T_K = (B * T_o)/((T_o * np.log(res1_25[i]/R_o)) + B)
    T_C = T_K - 273.15
    temps1_25.append(T_C)
    
for i in range(0, len(wavelengths2_15)):
    T_K = (B * T_o)/((T_o * np.log(res2_15[i]/R_o)) + B)
    T_C = T_K - 273.15
    temps2_15.append(T_C)
    
for i in range(0, len(wavelengths2_20)):
    T_K = (B * T_o)/((T_o * np.log(res2_20[i]/R_o)) + B)
    T_C = T_K - 273.15
    temps2_20.append(T_C)
    
for i in range(0, len(wavelengths2_25)):
    T_K = (B * T_o)/((T_o * np.log(res2_25[i]/R_o)) + B)
    T_C = T_K - 273.15
    temps2_25.append(T_C)

# %%
# Plotting temperature vs wavelength graph

# %%
import matplotlib.pyplot as plt
from scipy import stats

# %%
# line fit of data
fit1 = stats.linregress(wavelengths1_15, temps1_15)
fit2 = stats.linregress(wavelengths1_20, temps1_20)
fit3 = stats.linregress(wavelengths1_25, temps1_25)

fit4 = stats.linregress(wavelengths2_15, temps2_15)
fit5 = stats.linregress(wavelengths2_20, temps2_20)
fit6 = stats.linregress(wavelengths2_25, temps2_25)

# %%
fig, ax = plt.subplots()

plt.plot(wavelengths1_15, temps1_15, 'o', color='blue', label='15mA')
plt.plot(wavelengths1_20, temps1_20, '^', color='blue', label='20mA')
plt.plot(wavelengths1_25, temps1_25, 's', color='blue', label='25mA')
plt.plot(wavelengths2_15, temps2_15, 'o', color='red')
plt.plot(wavelengths2_20, temps2_20, '^', color='red')
plt.plot(wavelengths2_25, temps2_25, 's', color='red')

plt.plot(wavelengths1_15, fit1.intercept + fit1.slope*np.array(wavelengths1_15), 'b', label='laser1')
plt.plot(wavelengths1_20, fit2.intercept + fit2.slope*np.array(wavelengths1_20), 'b',)
plt.plot(wavelengths1_25, fit3.intercept + fit3.slope*np.array(wavelengths1_25), 'b')
plt.plot(wavelengths2_15, fit4.intercept + fit4.slope*np.array(wavelengths2_15), color='red', label='laser2')
plt.plot(wavelengths2_20, fit5.intercept + fit5.slope*np.array(wavelengths2_20), color='red')
plt.plot(wavelengths2_25, fit6.intercept + fit6.slope*np.array(wavelengths2_25), color='red')

#l1, = ax.plot(label="15mA",linestyle='dashdot', c='black')
#first_legend = ax.legend(handles=[l1], loc='bottom right')
#ax.add_artist(first_legend)

plt.legend()
plt.legend
plt.xlabel('Wavelength (nm)')
plt.ylabel('Temperature (C)')
plt.grid(linewidth=0.1)
plt.title('Two 670 nm lasers with temperature controller at different powers (2024-2-7)')
# plt.txt? couldn't get it to work
plt.show()

# %%
plt.plot(wavelengths1_15, temps1_15, 'o', color='blue', label='original data (laser1)')
plt.plot(wavelengths1_15, fit1.intercept + fit1.slope*np.array(wavelengths1_15), 'b', label='fitted line (laser1)')

plt.plot(wavelengths1_20, temps1_20, 'o', color='blue')
plt.plot(wavelengths1_20, fit2.intercept + fit2.slope*np.array(wavelengths1_20), 'b')

plt.plot(wavelengths1_25, temps1_25, 'o', color='blue')
plt.plot(wavelengths1_25, fit3.intercept + fit3.slope*np.array(wavelengths1_25), 'b')

plt.legend()
plt.xlabel('Wavelength (nm)')
plt.ylabel('Temperature (C)')
plt.grid(linewidth=0.1)
plt.title('670 nm laser diode with temperature controller (2024-2-7)')
# plt.txt? couldn't get it to work
plt.show()

# %%
print(fit1.slope)
print(fit2.slope)
print(fit3.slope)
# Out:
# 6.577680334133326
# 6.898444804201655
# 6.6094396378865214

# %%
plt.plot(wavelengths2_15, temps2_15, 'o', color='red', label='original data (laser2)')
plt.plot(wavelengths2_15, fit4.intercept + fit4.slope*np.array(wavelengths2_15), color='red', label='fitted line (laser2)')

plt.plot(wavelengths2_20, temps2_20, 'o', color='red')
plt.plot(wavelengths2_20, fit5.intercept + fit5.slope*np.array(wavelengths2_20), color='red')

plt.plot(wavelengths2_25, temps2_25, 'o', color='red')
plt.plot(wavelengths2_25, fit6.intercept + fit6.slope*np.array(wavelengths2_25), color='red')

plt.legend()
plt.xlabel('Wavelength (nm)')
plt.ylabel('Temperature (C)')
plt.grid(linewidth=0.1)
plt.title('670 nm laser diode with temperature controller (2024-2-7)')
# plt.txt? couldn't get it to work
plt.show()

# %%
print(fit4.slope)
print(fit5.slope)
print(fit6.slope)
# Out:
# 5.986189494954846
# 6.128572876528594
# 6.0386831369849086
